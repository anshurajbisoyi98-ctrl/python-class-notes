# %% [markdown]
# <a href="https://colab.research.google.com/github/anshurajbisoyi98-ctrl/python-class-notes/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a= input("enter a string")
reverseda=""
for i in range(len(a)-1,-1,-1):
  reverseda+=a[i]

if a==reverseda:
  print(" it is a palindrome")
else:
  print("it is not a palindrome")

# %%
lst =["hello",1,23,"mango",[1,2]]
print(lst)
# Out:
# ['hello', 1, 23, 'mango', [1, 2]]

# %%
lst.insert(2,24)

# %%
print(  lst)
# Out:
# [24]

# %%
lst.append("hii")

# %%
print(lst)
# Out:
# ['hello', 1, 23, 'mango', [1, 2], 'hii']

# %%
lst.clear()

# %%
print(lst)
# Out:
# []

# %%
ok=["hii","mango",23,4,5]
ok.append("anshu")
print(ok)
# Out:
# ['hii', 'mango', 23, 4, 5, 'anshu']

# %%
hii=ok.count(23)

# %%
er=[1,2,3,4,5,4,5,4,5]
er.count(5)
# Out:
# 3

# %%
print(er)
er.reverse()
print(er)
# Out:
# [4, 'hello world', 5, 4, 5, 4, 3, 2, 'hello world', 'hello world', 'hello world', 'hello world', 'hello world', 'hello world', 'hello world', 'hello world', 1]
# [1, 'hello world', 'hello world', 'hello world', 'hello world', 'hello world', 'hello world', 'hello world', 'hello world', 2, 3, 4, 5, 4, 5, 'hello world', 4]

# %%
print(hii)
# Out:
# ['hii', 'mango', 23, 4, 5, 'anshu']

# %%
er=[1,2,6,4,5,4,5,4,5]
er.sort()
print ()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_743/2579629301.py in <cell line: 0>()
#       1 er=[1,2,6,4,5,4,5,4,5]
#       2 er.sort()
# ----> 3 print (sort(er))
#
# NameError: name 'sort' is not defined

# %%
oy=[1,3,5,6,3,2,3,2,5,6,7,9,5]
sm=sum(oy)
print(sm)
print(min(oy))
print(sorted(oy))
# Out:
# 57
# 1
# [1, 2, 2, 3, 3, 3, 5, 5, 5, 6, 6, 7, 9]

# %%
oy={1,3,5,6,3,2,3,2,5,6,7,9,5}
