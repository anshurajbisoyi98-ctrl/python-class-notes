# %% [markdown]
# <a href="https://colab.research.google.com/github/anshurajbisoyi98-ctrl/python-class-notes/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
dict = {
    'name':['anshu','ritesh','ankit'],
    'age' :[18,19,20],
    'roll':[1,2,3]
}
df = pd.DataFrame(dict)
print(df)
display(df)
df= pd.read_csv('/content/student_data.csv')
display(df.head())
# Out:
#      name  age  roll
# 0   anshu   18     1
# 1  ritesh   19     2
# 2   ankit   20     3
#      name  age  roll
# 0   anshu   18     1
# 1  ritesh   19     2
# 2   ankit   20     3
#    study_hours  attendance  sleep_hours  internet_usage  \
# 0            7          56            8               7
# 1            4          69            5               3
# 2           11          60            7               6
# 3            8          99            9               8
# 4            5          52            8               6
#
#    assignments_completed  previous_score  exam_score placement_status
# 0                     10              62      100.00           Placed
# 1                      8              56      100.00           Placed
# 2                     10              45      100.00           Placed
# 3                      4              55       90.17           Placed
# 4                      8              40       78.82           Placed

# %%
df= pd.read_csv('/content/student_data.csv')
display(df.head())
# Out:
#    study_hours  attendance  sleep_hours  internet_usage  \
# 0            7          56            8               7
# 1            4          69            5               3
# 2           11          60            7               6
# 3            8          99            9               8
# 4            5          52            8               6
#
#    assignments_completed  previous_score  exam_score placement_status
# 0                     10              62      100.00           Placed
# 1                      8              56      100.00           Placed
# 2                     10              45      100.00           Placed
# 3                      4              55       90.17           Placed
# 4                      8              40       78.82           Placed

# %%
a=df.describe()
display(a)
#q1 quartile is the median of the data of one part 25% is the first qurtile than second qurartile than third quartile
# Out:
#         study_hours   attendance   sleep_hours  internet_usage  \
# count  10000.000000  10000.00000  10000.000000    10000.000000
# mean       5.989600     69.88460      6.498500        6.062600
# std        3.163589     17.61653      1.709354        3.138163
# min        1.000000     40.00000      4.000000        1.000000
# 25%        3.000000     55.00000      5.000000        3.000000
# 50%        6.000000     70.00000      6.500000        6.000000
# 75%        9.000000     85.00000      8.000000        9.000000
# max       11.000000    100.00000      9.000000       11.000000
#
#        assignments_completed  previous_score    exam_score
# count           10000.000000     10000.00000  10000.000000
# mean                9.988400        64.91100     86.704207
# std                 6.034145        17.50302     15.058383
# min                 0.000000        35.00000     26.670000
# 25%                 5.000000        50.00000     76.727500
# ...

# %%
#median is the number at index n/2 if odd 2 numbers will be median if it is even than their average

# %%
df[["study_hours","sleep_hours"]]
# Out:
#       study_hours  sleep_hours
# 0               7            8
# 1               4            5
# 2              11            7
# 3               8            9
# 4               5            8
# ...           ...          ...
# 9995            2            9
# 9996            7            6
# 9997           10            8
# 9998           10            7
# 9999            2            6
#
# [10000 rows x 2 columns]

# %%
df.tail(5)
df.head(5)
# Out:
#    study_hours  attendance  sleep_hours  internet_usage  \
# 0            7          56            8               7
# 1            4          69            5               3
# 2           11          60            7               6
# 3            8          99            9               8
# 4            5          52            8               6
#
#    assignments_completed  previous_score  exam_score placement_status
# 0                     10              62      100.00           Placed
# 1                      8              56      100.00           Placed
# 2                     10              45      100.00           Placed
# 3                      4              55       90.17           Placed
# 4                      8              40       78.82           Placed

# %%
df.iloc[0:5]
# Out:
#    study_hours  attendance  sleep_hours  internet_usage  \
# 0            7          56            8               7
# 1            4          69            5               3
# 2           11          60            7               6
# 3            8          99            9               8
# 4            5          52            8               6
#
#    assignments_completed  previous_score  exam_score placement_status
# 0                     10              62      100.00           Placed
# 1                      8              56      100.00           Placed
# 2                     10              45      100.00           Placed
# 3                      4              55       90.17           Placed
# 4                      8              40       78.82           Placed

# %%
df.loc[df['study_hours']==11]
df.loc[df['study_hours']==11,['study_hours']]
# Out:
#       study_hours
# 2              11
# 9              11
# 10             11
# 29             11
# 30             11
# ...           ...
# 9969           11
# 9971           11
# 9978           11
# 9979           11
# 9988           11
#
# [868 rows x 1 columns]

# %%
df.loc[4]
# Out:
# study_hours                   5
# attendance                   52
# sleep_hours                   8
# internet_usage                6
# assignments_completed         8
# previous_score               40
# exam_score                78.82
# placement_status         Placed
# Name: 4, dtype: object

# %%
df.loc[df['study_hours']==11,['study_hours','sleep_hours']].iloc[4:8]
# Out:
#      study_hours  sleep_hours
# 30            11            5
# 91            11            9
# 98            11            6
# 116           11            7

# %%
(df["previous_score"] > 75) | (df["exam_score"] < 87)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 9995     True
# 9996     True
# 9997    False
# 9998    False
# 9999     True
# Length: 10000, dtype: bool

# %%
df.loc[df['assignments_completed']==8].iloc[2]
# Out:
# study_hours                   4
# attendance                   98
# sleep_hours                   9
# internet_usage                2
# assignments_completed         8
# previous_score               70
# exam_score                100.0
# placement_status         Placed
# Name: 13, dtype: object

# %%
df=pd.read_csv('student_data.csv')
df[df["assignments_completed"]>3]
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  \
# 0               7          56            8               7
# 1               4          69            5               3
# 2              11          60            7               6
# 3               8          99            9               8
# 4               5          52            8               6
# ...           ...         ...          ...             ...
# 9995            2          58            9               7
# 9996            7          98            6               9
# 9997           10          44            8               5
# 9998           10          75            7               5
# 9999            2          70            6              11
#
#       assignments_completed  previous_score  exam_score placement_status
# 0                        10              62      100.00           Placed
# 1                         8              56      100.00           Placed
# ...

# %%
#rename columns
df.rename(columns={'assignments_completed': 'assign_completed'}, inplace=True)
display(df)
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  assign_completed  \
# 0               7          56            8               7                10
# 1               4          69            5               3                 8
# 2              11          60            7               6                10
# 3               8          99            9               8                 4
# 4               5          52            8               6                 8
# ...           ...         ...          ...             ...               ...
# 9995            2          58            9               7                 8
# 9996            7          98            6               9                 4
# 9997           10          44            8               5                10
# 9998           10          75            7               5                 8
# 9999            2          70            6              11                16
#
# ...

# %%
df.drop([3,4])#delete rows from df.drop([start,end])
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  assign_completed  \
# 0               7          56            8               7                10
# 1               4          69            5               3                 8
# 2              11          60            7               6                10
# 5               7          40            9              10                 0
# 6              10          40            4              11                 9
# ...           ...         ...          ...             ...               ...
# 9995            2          58            9               7                 8
# 9996            7          98            6               9                 4
# 9997           10          44            8               5                10
# 9998           10          75            7               5                 8
# 9999            2          70            6              11                16
#
# ...

# %%
df.dropna(how="all")
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  assign_completed  \
# 0               7          56            8               7                10
# 1               4          69            5               3                 8
# 2              11          60            7               6                10
# 3               8          99            9               8                 4
# 4               5          52            8               6                 8
# ...           ...         ...          ...             ...               ...
# 9995            2          58            9               7                 8
# 9996            7          98            6               9                 4
# 9997           10          44            8               5                10
# 9998           10          75            7               5                 8
# 9999            2          70            6              11                16
#
# ...

# %%
df.sort_values(by=['study_hours', 'attendance'])
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  assign_completed  \
# 1079            1          40            9               2                13
# 1481            1          40            5               9                17
# 2519            1          40            7              10                14
# 3445            1          40            8               7                16
# 6353            1          40            7               7                20
# ...           ...         ...          ...             ...               ...
# 6588           11         100            9              11                16
# 7076           11         100            6               1                10
# 7570           11         100            4               2                 1
# 8122           11         100            7               1                15
# 9865           11         100            9               8                 2
#
# ...

# %%
df.sort_index()
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  assign_completed  \
# 0               7          56            8               7                10
# 1               4          69            5               3                 8
# 2              11          60            7               6                10
# 3               8          99            9               8                 4
# 4               5          52            8               6                 8
# ...           ...         ...          ...             ...               ...
# 9995            2          58            9               7                 8
# 9996            7          98            6               9                 4
# 9997           10          44            8               5                10
# 9998           10          75            7               5                 8
# 9999            2          70            6              11                16
#
# ...

# %%
df.isnull()
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  assign_completed  \
# 0           False       False        False           False             False
# 1           False       False        False           False             False
# 2           False       False        False           False             False
# 3           False       False        False           False             False
# 4           False       False        False           False             False
# ...           ...         ...          ...             ...               ...
# 9995        False       False        False           False             False
# 9996        False       False        False           False             False
# 9997        False       False        False           False             False
# 9998        False       False        False           False             False
# 9999        False       False        False           False             False
#
# ...

# %%
df.notnull()
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  assign_completed  \
# 0            True        True         True            True              True
# 1            True        True         True            True              True
# 2            True        True         True            True              True
# 3            True        True         True            True              True
# 4            True        True         True            True              True
# ...           ...         ...          ...             ...               ...
# 9995         True        True         True            True              True
# 9996         True        True         True            True              True
# 9997         True        True         True            True              True
# 9998         True        True         True            True              True
# 9999         True        True         True            True              True
#
# ...

# %%
df.fillna(0)#replace na/0  values with whatever inside the bracket
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  assign_completed  \
# 0               7          56            8               7                10
# 1               4          69            5               3                 8
# 2              11          60            7               6                10
# 3               8          99            9               8                 4
# 4               5          52            8               6                 8
# ...           ...         ...          ...             ...               ...
# 9995            2          58            9               7                 8
# 9996            7          98            6               9                 4
# 9997           10          44            8               5                10
# 9998           10          75            7               5                 8
# 9999            2          70            6              11                16
#
# ...
